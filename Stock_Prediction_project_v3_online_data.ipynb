# %% [markdown]
# # STOCK PREDICTION PROJECT v3 - ONLINE DATA

# %%
# Import Packages
import pandas as pd
from scipy import stats
import numpy as np

from copy import copy
import datetime

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go


import pandas_datareader.data as web

# %%
start = datetime.datetime(2015, 1, 1)
end = datetime.datetime(2020, 12, 25)

# %%
stock_df = web.DataReader('AAPL',  'ff' , start, end)
stock_df.head()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-11-a1270895c0c9> in <module>()
# ----> 1 stock_df = web.DataReader('AAPL',  'ff' , start, end)
#       2 stock_df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     371     if data_source not in expected_source:
#     372         msg = "data_source=%r is not implemented" % data_source
# --> 373         raise NotImplementedError(msg)
#     374
#     375     if data_source == "yahoo":
#
# ...

# %%
# !pip install quandl

# %%
import quandl

# %%
stock_df = quandl.get('WIKI/AAPL')
stock_df.head(2)
# Out:
#              Open   High    Low  ...  Adj. Low  Adj. Close  Adj. Volume
# Date                             ...
# 1980-12-12  28.75  28.87  28.75  ...  0.422706    0.422706  117258400.0
# 1980-12-15  27.38  27.38  27.25  ...  0.400652    0.400652   43971200.0
#
# [2 rows x 12 columns]

# %%
stock_df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Ex-Dividend', 'Split Ratio',
#        'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume'],
#       dtype='object')

# %%
stock_df.sort_values( by='Date')
# Out:
#               Open    High     Low  ...    Adj. Low  Adj. Close  Adj. Volume
# Date                                ...
# 1980-12-12   28.75   28.87   28.75  ...    0.422706    0.422706  117258400.0
# 1980-12-15   27.38   27.38   27.25  ...    0.400652    0.400652   43971200.0
# 1980-12-16   25.37   25.37   25.25  ...    0.371246    0.371246   26432000.0
# 1980-12-17   25.87   26.00   25.87  ...    0.380362    0.380362   21610400.0
# 1980-12-18   26.63   26.75   26.63  ...    0.391536    0.391536   18362400.0
# ...            ...     ...     ...  ...         ...         ...          ...
# 2018-03-21  175.04  175.09  171.26  ...  171.260000  171.270000   35247358.0
# 2018-03-22  170.00  172.68  168.60  ...  168.600000  168.845000   41051076.0
# 2018-03-23  168.39  169.92  164.94  ...  164.940000  164.940000   40248954.0
# 2018-03-26  168.07  173.10  166.44  ...  166.440000  172.770000   36272617.0
# 2018-03-27  173.68  175.15  166.92  ...  166.920000  168.340000   38962839.0
#
# ...

# %%
stock_df = stock_df.drop(columns=['Open', 'High', 'Low', 'Close', 'Volume', 'Ex-Dividend', 'Split Ratio',
       'Adj. Open', 'Adj. High', 'Adj. Low'])
stock_df.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1980-12-12    0.422706  117258400.0
# 1980-12-15    0.400652   43971200.0
# 1980-12-16    0.371246   26432000.0
# 1980-12-17    0.380362   21610400.0
# 1980-12-18    0.391536   18362400.0

# %%
stock_df.index
# Out:
# DatetimeIndex(['1980-12-12', '1980-12-15', '1980-12-16', '1980-12-17',
#                '1980-12-18', '1980-12-19', '1980-12-22', '1980-12-23',
#                '1980-12-24', '1980-12-26',
#                ...
#                '2018-03-14', '2018-03-15', '2018-03-16', '2018-03-19',
#                '2018-03-20', '2018-03-21', '2018-03-22', '2018-03-23',
#                '2018-03-26', '2018-03-27'],
#               dtype='datetime64[ns]', name='Date', length=9400, freq=None)

# %%
# Reindex dataframe to include Date as a field

stock_df['Date'] = pd.to_datetime(df['date'], format='Y%m%d') and then df1 = df.set_index('date')

# %%
def norm_data(df):
  x = df.copy()
  for i in x.columns:#[1:]:
    x[i] = x[i]/x[i][0]

  return x

# %%
def interactive_plot(df, title):
  fig = px.line(title = title)
  for i in df.columns:#[1:]:
    fig.add_scatter(x = df.index, y = df[i], name = i)
  fig.show()

# %%
# Plot raw stock data
interactive_plot(stock_df, 'RAW AAPL STOCK DATA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2081c4ac-14d7-4bcb-b5cf-f54eede270d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2081c4ac-14d7-4bcb-b5cf-f54eede270d7")) {
#                     Plotly.newPlot(
#                         '2081c4ac-14d7-4bcb-b5cf-f54eede270d7',
# ...

# %%
# Plot normalized stock data
interactive_plot(norm_data(stock_df), 'NORMALIZED AAPL STOCK DATA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2f452b33-e5b4-48e9-b2b5-4ad3904e34b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2f452b33-e5b4-48e9-b2b5-4ad3904e34b9")) {
#                     Plotly.newPlot(
#                         '2f452b33-e5b4-48e9-b2b5-4ad3904e34b9',
# ...
